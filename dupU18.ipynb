# %%
import pandas as pd

# %%
df = pd.read_csv('PlayersU18.csv')
df1 = pd.read_csv('U18_minutes.csv')

# %%
df
# Out:
#       Unnamed: 0            season  rank                 player  \
# 0              0  2020-21 VALENCIA     1         SOCHAN, JEREMY
# 1              1  2020-21 VALENCIA     2       CAICEDO, MICHAEL
# 2              2  2020-21 VALENCIA     3           VILLAR, RAFA
# 3              3  2020-21 VALENCIA     4   LOEMBA, MARC-ANTOINE
# 4              4  2020-21 VALENCIA     5        RAYNAUD, MAXIME
# ...          ...               ...   ...                    ...
# 5660        5660           2002-03    89    GIANNAKIS, DIMITRIS
# 5661        5661           2002-03    90  STRASEVICIUS, SARUNAS
# 5662        5662           2002-03    90         MUBARAK, MOSES
# 5663        5663           2002-03    92       MAXIMOV, SERGIOS
# 5664        5664           2002-03    93        KULENOVIC, EMIR
#
#                               team  games  index  average  per_40min
# 0               U18 ratiopharm Ulm      4     90    22.50      29.02
# 1                 U18 FC Barcelona      4     78    19.50      28.29
# 2                 U18 FC Barcelona      4     76    19.00      34.18
# 3                  U18 Nanterre 92      4     67    16.75      22.03
# 4                  U18 Nanterre 92      4     65    16.25      18.83
# ...                            ...    ...    ...      ...        ...
# 5660                U18 AEK ATHENS      3     -7    -2.33      -7.57
# 5661           U18 ZALGIRIS KAUNAS      3     -8    -2.67     -10.67
# 5662  U18 ELAN BEARNAIS PAU ORTHEZ      3     -8    -2.67      -9.14
# 5663                U18 AEK ATHENS      3    -10    -3.33      -8.16
# 5664  U18 UNION OLIMPIJA LJUBLJANA      3    -11    -3.67      -9.57
#
# [5665 rows x 9 columns]

# %%
playersIndex = df.drop('Unnamed: 0', axis=1)

# %%
playersIndex.columns = playersIndex.columns.str.strip()

# %%
playersMinutes = df1.drop('Unnamed: 0', axis=1)

# %%
playersMinutes.columns = playersMinutes.columns.str.strip()

# %%
playersMinutes
# Out:
#                 season  rank                player  \
# 0     2020-21 VALENCIA     1        KASIAMA, KENNY
# 1     2020-21 VALENCIA     2       RAYNAUD, MAXIME
# 2     2020-21 VALENCIA     3      HOUINSOU, KYMANY
# 3     2020-21 VALENCIA     4        SOCHAN, JEREMY
# 4     2020-21 VALENCIA     5  LOEMBA, MARC-ANTOINE
# ...                ...   ...                   ...
# 5660           2002-03    89      PSIRIS, SOTIRIOS
# 5661           2002-03    90     DRITSOS, GEORGIOS
# 5662           2002-03    90     KIRIAKIDIS, SAVAS
# 5663           2002-03    90   KORKIDIS, EVANGELOS
# 5664           2002-03    93     SHIFER, YEHONATAN
#
#                              team  games minutes
# 0     U18 LDLC ASVEL Villeurbanne      4  138:57
# 1                 U18 Nanterre 92      4  138:04
# 2     U18 LDLC ASVEL Villeurbanne      4  136:08
# 3              U18 ratiopharm Ulm      4  124:02
# 4                 U18 Nanterre 92      4  121:38
# ...                           ...    ...     ...
# 5660               U18 AEK ATHENS      2    4:00
# 5661               U18 AEK ATHENS      1    2:00
# 5662               U18 AEK ATHENS      1    2:00
# 5663               U18 AEK ATHENS      1    2:00
# 5664         U18 MACCABI TEL AVIV      1    1:00
#
# [5665 rows x 6 columns]

# %%
baseU18 = playersIndex.merge(playersMinutes[['season', 'player', 'team', 'games', 'minutes']],'left',on=['season', 'player', 'team', 'games'],suffixes=('', 'minutes'))

# %%
baseU18
# Out:
#                 season  rank                 player  \
# 0     2020-21 VALENCIA     1         SOCHAN, JEREMY
# 1     2020-21 VALENCIA     2       CAICEDO, MICHAEL
# 2     2020-21 VALENCIA     3           VILLAR, RAFA
# 3     2020-21 VALENCIA     4   LOEMBA, MARC-ANTOINE
# 4     2020-21 VALENCIA     5        RAYNAUD, MAXIME
# ...                ...   ...                    ...
# 5662           2002-03    89    GIANNAKIS, DIMITRIS
# 5663           2002-03    90  STRASEVICIUS, SARUNAS
# 5664           2002-03    90         MUBARAK, MOSES
# 5665           2002-03    92       MAXIMOV, SERGIOS
# 5666           2002-03    93        KULENOVIC, EMIR
#
#                               team  games  index  average  per_40min minutes
# 0               U18 ratiopharm Ulm      4     90    22.50      29.02  124:02
# 1                 U18 FC Barcelona      4     78    19.50      28.29  110:17
# 2                 U18 FC Barcelona      4     76    19.00      34.18   88:56
# 3                  U18 Nanterre 92      4     67    16.75      22.03  121:38
# 4                  U18 Nanterre 92      4     65    16.25      18.83  138:04
# ...                            ...    ...    ...      ...        ...     ...
# 5662                U18 AEK ATHENS      3     -7    -2.33      -7.57   37:00
# 5663           U18 ZALGIRIS KAUNAS      3     -8    -2.67     -10.67   30:00
# 5664  U18 ELAN BEARNAIS PAU ORTHEZ      3     -8    -2.67      -9.14   35:00
# 5665                U18 AEK ATHENS      3    -10    -3.33      -8.16   49:00
# 5666  U18 UNION OLIMPIJA LJUBLJANA      3    -11    -3.67      -9.57   46:00
#
# [5667 rows x 9 columns]

# %%
dup_index = baseU18.groupby(['player'])['index'].transform(max) == baseU18['index']
base_index = baseU18[dup_index].sort_values(by=['player'])

# %%
base_index
# Out:
#                  season  rank               player  \
# 654      2018-19 KAUNAS     4          ABAD, MAURO
# 3142            2012-13    11      ABALDE, ALBERTO
# 5622            2002-03    47        ABBAD, ROMAIN
# 4542            2009-10   286          ABIA, LARRY
# 2131     2015-16 KAUNAS    67  ABRAHA, FEKREMARIAM
# ...                 ...   ...                  ...
# 89     2020-21 VALENCIA    89      ZULEMIE, NATHAN
# 4895            2008-09   222       ZUYKOV, DANYLO
# 3882            2011-12   343       ZVEREV, NIKITA
# 3574            2011-12    39       ZVIGURS, IVARS
# 1978  2015-16  BELGRADE    10     ZYLKA, FERDINAND
#
#                                             team  games  index  average  \
# 654              U18 TORRONS VICENS L'HOSPITALET      4     74    18.50
# 3142                  IJT CLUB JOVENTUT BADALONA      9    115    12.78
# 5622                U18 ELAN BEARNAIS PAU ORTHEZ      3      9     3.00
# 4542                       IJT POWER ELECTRONICS      3      4     1.33
# 2131  U18 PORSCHE BASKETBALL ACADEMY LUDWIGSBURG      3      2     0.67
# ...                                          ...    ...    ...      ...
# 89                               U18 Nanterre 92      4     -5    -1.25
# 4895                                     BC KYIV      4      8     2.00
# 3882                 IJT BC KHIMKI MOSCOW REGION      3      0     0.00
# 3574                                IJT VEF RIGA      4     69    17.25
# 1978                             U18 ALBA BERLIN      4     85    21.25
#
#       per_40min minutes
# 654       29.37  100:46
# 3142      19.82  232:08
# 5622       4.86   74:00
# 4542       3.73   42:54
# 2131       1.95   40:56
# ...         ...     ...
# 89        -3.02   66:07
# 4895       2.64  121:01
# 3882       0.00   10:11
# 3574      20.97  131:38
# 1978      30.48  111:33
#
# [3971 rows x 9 columns]

# %%
dup_avg = base_index.groupby(['player'])['average'].transform(max) == base_index['average']
base = base_index[dup_avg].sort_values(by=['player'])

# %%
base
# Out:
#                  season  rank               player  \
# 654      2018-19 KAUNAS     4          ABAD, MAURO
# 3142            2012-13    11      ABALDE, ALBERTO
# 5622            2002-03    47        ABBAD, ROMAIN
# 4542            2009-10   286          ABIA, LARRY
# 2131     2015-16 KAUNAS    67  ABRAHA, FEKREMARIAM
# ...                 ...   ...                  ...
# 89     2020-21 VALENCIA    89      ZULEMIE, NATHAN
# 4895            2008-09   222       ZUYKOV, DANYLO
# 3882            2011-12   343       ZVEREV, NIKITA
# 3574            2011-12    39       ZVIGURS, IVARS
# 1978  2015-16  BELGRADE    10     ZYLKA, FERDINAND
#
#                                             team  games  index  average  \
# 654              U18 TORRONS VICENS L'HOSPITALET      4     74    18.50
# 3142                  IJT CLUB JOVENTUT BADALONA      9    115    12.78
# 5622                U18 ELAN BEARNAIS PAU ORTHEZ      3      9     3.00
# 4542                       IJT POWER ELECTRONICS      3      4     1.33
# 2131  U18 PORSCHE BASKETBALL ACADEMY LUDWIGSBURG      3      2     0.67
# ...                                          ...    ...    ...      ...
# 89                               U18 Nanterre 92      4     -5    -1.25
# 4895                                     BC KYIV      4      8     2.00
# 3882                 IJT BC KHIMKI MOSCOW REGION      3      0     0.00
# 3574                                IJT VEF RIGA      4     69    17.25
# 1978                             U18 ALBA BERLIN      4     85    21.25
#
#       per_40min minutes
# 654       29.37  100:46
# 3142      19.82  232:08
# 5622       4.86   74:00
# 4542       3.73   42:54
# 2131       1.95   40:56
# ...         ...     ...
# 89        -3.02   66:07
# 4895       2.64  121:01
# 3882       0.00   10:11
# 3574      20.97  131:38
# 1978      30.48  111:33
#
# [3960 rows x 9 columns]

# %%
base.to_csv('baseU18.csv')
