# %%
import pandas as pd

# %%
df = pd.read_csv('index_eurocup.csv')
df1 = pd.read_csv('minutes_eurocup.csv')

# %%
df
# Out:
#       Unnamed: 0   season  rank             player                      team  \
# 0              0  2020-21     1   LESSORT, MATHIAS                 AS Monaco
# 1              1  2020-21     2    TEODOSIC, MILOS  Virtus Segafredo Bologna
# 2              2  2020-21     3        BROWN, JOHN               UNICS Kazan
# 3              3  2020-21     4       SMITH, JAMAR               UNICS Kazan
# 4              4  2020-21     5     KNIGHT, MARCOS                 AS Monaco
# ...          ...      ...   ...                ...                       ...
# 7487        7487  2002-03   329  POPOVIC, SLOBODAN              FMP Belgrade
# 7488        7488  2002-03   329     TOLBERT, BRIAN            Snaidero Udine
# 7489        7489  2002-03   331     SYLVERE, BRYAN             Cholet Basket
# 7490        7490  2002-03   332   TERDENGE, GERRIT      RheinEnergie Cologne
# 7491        7491  2002-03   332      MAJOR, GERRIT                    Ostend
#
#       games  index  average  per_40min
# 0        23    409    17.78      28.96
# 1        19    362    19.05      27.71
# 2        24    347    14.46      22.32
# 3        22    345    15.68      23.34
# 4        23    330    14.35      21.37
# ...     ...    ...      ...        ...
# 7487      5     -7    -1.40      -8.00
# 7488      2     -7    -3.50     -10.77
# 7489      7     -8    -1.14      -6.53
# 7490     11     -9    -0.82      -3.86
# 7491      6     -9    -1.50      -3.16
#
# [7492 rows x 9 columns]

# %%
playersIndex = df.drop('Unnamed: 0', axis=1)

# %%
playersIndex.columns = playersIndex.columns.str.strip()

# %%
playersMinutes = df1.drop('Unnamed: 0', axis=1)

# %%
playersMinutes.columns = playersMinutes.columns.str.strip()

# %%
playersMinutes
# Out:
#        season  rank             player                    team  games minutes
# 0     2020-21     1     CANAAN, ISAIAH             UNICS Kazan     24  646:45
# 1     2020-21     2          BOST, DEE               AS Monaco     22  634:42
# 2     2020-21     3        BROWN, JOHN             UNICS Kazan     24  621:49
# 3     2020-21     4     KNIGHT, MARCOS               AS Monaco     23  617:43
# 4     2020-21     5    O'BRIEN, JALEEL               AS Monaco     23  610:51
# ...       ...   ...                ...                     ...    ...     ...
# 7487  2002-03   328  CVJETKOVIC, NENAD        Ricoh Astronauts      1    1:00
# 7488  2002-03   328    AGAPITO, DAVIDE  Generali Group Trieste      1    1:00
# 7489  2002-03   328     SCAPIN, MATTEO    Eurocellulari Roseto      1    1:00
# 7490  2002-03   328    VIDOVIC, SANJIN            Telekom Bonn      1    1:00
# 7491  2002-03   328    SPAHIJA, JURICA          BCM Gravelines      1    1:00
#
# [7492 rows x 6 columns]

# %%
baseU18 = playersIndex.merge(playersMinutes[['season', 'player', 'team', 'games', 'minutes']],'left',on=['season', 'player', 'team', 'games'],suffixes=('', 'minutes'))

# %%
baseU18
# Out:
#        season  rank             player                      team  games  \
# 0     2020-21     1   LESSORT, MATHIAS                 AS Monaco     23
# 1     2020-21     2    TEODOSIC, MILOS  Virtus Segafredo Bologna     19
# 2     2020-21     3        BROWN, JOHN               UNICS Kazan     24
# 3     2020-21     4       SMITH, JAMAR               UNICS Kazan     22
# 4     2020-21     5     KNIGHT, MARCOS                 AS Monaco     23
# ...       ...   ...                ...                       ...    ...
# 7487  2002-03   329  POPOVIC, SLOBODAN              FMP Belgrade      5
# 7488  2002-03   329     TOLBERT, BRIAN            Snaidero Udine      2
# 7489  2002-03   331     SYLVERE, BRYAN             Cholet Basket      7
# 7490  2002-03   332   TERDENGE, GERRIT      RheinEnergie Cologne     11
# 7491  2002-03   332      MAJOR, GERRIT                    Ostend      6
#
#       index  average  per_40min minutes
# 0       409    17.78      28.96  565:00
# 1       362    19.05      27.71  522:38
# 2       347    14.46      22.32  621:49
# 3       345    15.68      23.34  591:13
# 4       330    14.35      21.37  617:43
# ...     ...      ...        ...     ...
# 7487     -7    -1.40      -8.00   35:00
# 7488     -7    -3.50     -10.77   26:00
# 7489     -8    -1.14      -6.53   49:00
# 7490     -9    -0.82      -3.86   93:10
# 7491     -9    -1.50      -3.16  114:00
#
# [7492 rows x 9 columns]

# %%
dup_index = baseU18.groupby(['player'])['index'].transform(max) == baseU18['index']
base_index = baseU18[dup_index].sort_values(by=['player'])

# %%
base_index
# Out:
#        season  rank             player                      team  games  \
# 5422  2007-08   282      AARTS, MARCEL    EiffelTowers Den Bosch     10
# 800   2018-19    95    ABALDE, ALBERTO           Valencia Basket     23
# 381   2019-20    22       ABASS, AWUDU  Germani Brescia Leonessa     15
# 7276  2002-03   118  ABBIO, ALESSANDRO           Pamesa Valencia      9
# 2947  2013-14   342         ABBOTT, TY       Kalev Cramo Tallinn      9
# ...       ...   ...                ...                       ...    ...
# 6927  2003-04   219       ZUZA, JURICA   Ionikos NF Egnatia Bank      6
# 4574  2009-10   265   ZVARYKIN, VICTOR                     Unics      7
# 1639  2016-17   230     ZVEREV, NIKITA           Nizhny Novgorod      9
# 3419  2012-13   361     ZVIGURS, IVARS                  VEF Riga      1
# 2565  2014-15   411   ZWIENER, PHILLIP     EWE Baskets Oldenburg     10
#
#       index  average  per_40min minutes
# 5422     75     7.50      16.81  178:31
# 800     127     5.52      13.88  365:52
# 381     194    12.93      19.49  398:07
# 7276     88     9.78      16.68  211:00
# 2947     66     7.33       9.66  273:17
# ...     ...      ...        ...     ...
# 6927     60    10.00      18.50  129:45
# 4574     23     3.29       9.93   92:39
# 1639     13     1.44       8.49   61:14
# 3419      2     2.00      70.59    1:08
# 2565     28     2.80       7.51  149:06
#
# [3853 rows x 9 columns]

# %%
dup_avg = base_index.groupby(['player'])['average'].transform(max) == base_index['average']
base = base_index[dup_avg].sort_values(by=['player'])

# %%
base
# Out:
#        season  rank             player                      team  games  \
# 5422  2007-08   282      AARTS, MARCEL    EiffelTowers Den Bosch     10
# 800   2018-19    95    ABALDE, ALBERTO           Valencia Basket     23
# 381   2019-20    22       ABASS, AWUDU  Germani Brescia Leonessa     15
# 7276  2002-03   118  ABBIO, ALESSANDRO           Pamesa Valencia      9
# 2947  2013-14   342         ABBOTT, TY       Kalev Cramo Tallinn      9
# ...       ...   ...                ...                       ...    ...
# 6927  2003-04   219       ZUZA, JURICA   Ionikos NF Egnatia Bank      6
# 4574  2009-10   265   ZVARYKIN, VICTOR                     Unics      7
# 1639  2016-17   230     ZVEREV, NIKITA           Nizhny Novgorod      9
# 3419  2012-13   361     ZVIGURS, IVARS                  VEF Riga      1
# 2565  2014-15   411   ZWIENER, PHILLIP     EWE Baskets Oldenburg     10
#
#       index  average  per_40min minutes
# 5422     75     7.50      16.81  178:31
# 800     127     5.52      13.88  365:52
# 381     194    12.93      19.49  398:07
# 7276     88     9.78      16.68  211:00
# 2947     66     7.33       9.66  273:17
# ...     ...      ...        ...     ...
# 6927     60    10.00      18.50  129:45
# 4574     23     3.29       9.93   92:39
# 1639     13     1.44       8.49   61:14
# 3419      2     2.00      70.59    1:08
# 2565     28     2.80       7.51  149:06
#
# [3836 rows x 9 columns]

# %%
base.to_csv('baseEurocup.csv')
